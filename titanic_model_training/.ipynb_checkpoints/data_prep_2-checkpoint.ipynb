# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split 
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# %%
from Titanic import TitanicModel
from Titanic import titanic_preprocess
model = TitanicModel()
df = pd.read_csv('test.csv')
Titanic.titanic_preprocess(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 2
#       1 from Titanic import TitanicModel
# ----> 2 from Titanic import titanic_preprocess
#       3 model = TitanicModel()
#       4 df = pd.read_csv('test.csv')
#
# ImportError: cannot import name 'titanic_preprocess' from 'Titanic' (/Users/Mcdizzo/Documents/Jupyterlab_ML/titanic/Titanic.py)
